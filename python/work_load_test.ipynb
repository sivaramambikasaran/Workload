# %% [markdown]
# # Work load
#
# The following is the test case used for testing the workload applet.
#
# The following csv files are assumed to be in place
#     * course preference
#     * faculty requirement
#     * workload history
#
# The code outputs a provisional list for UG

# %%
UG_COURSE_LIMIT = 3
COURSE_PER_CYCLE = 6 # 4 semester is a cycle
NUM_PREFERENCES = 4
NUM_TIE_RULES = 3

# Define ties here as functions


class faculty:
    """Class for professor data, this holds the information needed for calculating the workload.
    Also this stores the provisional allotment
    """
    def __init__(self, data):
        # Information of a professor
        self.name = data[0]
        self.smail = data[1]
        self.priority_key = data[2]
        self.ug_corse_count_left = UG_COURSE_LIMIT - data[3]  # data[3] - UG courses taught in previous cycle
        self.pg_course_count_left = COURSE_PER_CYCLE - data[4]  - data[3]
        self.course_preferences = data[5]
        self.current_allotment = []
        self.course_count = self.ug_corse_count + self.pg_course_count

    def can_accommodate_ug(self):
        if self.course_count == COURSE_PER_CYCLE:
            return False
        if self.ug_corse_count == UG_COURSE_LIMIT:
            return False
        return True

    def can_accommodate_pg(self):
        if self.course_count == COURSE_PER_CYCLE:
            return False
        return True
    
    def allot_course(self, course_):
        self.current_allotment.append(course_)

    def tie_rule_1(self,fac):
        # Number of UG courses left in cycle
        if self.ug_corse_count_left < fac.ug_course_count_left:
            return fac
        if self.ug_corse_count_left > fac.ug_course_count_left:
            return self
        return None

    def tie_rule_2(self, fac2):
        return fac1
    
# Adding more ties can be done but the final TIE rule must return a single value
    def tie_rule_3(self, fac2):
        if self.priority_key < fac2.priority_key :
            return self
        else:
            return fac2

    # Add ties as and when needed 
    def tie_settle(fac1,fac2):
        if fac1.tie_rule_1(fac2) != None:
            return fac1.tie_rule_1(fac2)
        if fac1.tie_rule_2(fac2) != None:
            return fac1.tie_rule_2(fac2)
        if fac1.tie_rule_3(fac2) != None:
            return fac1.tie_rule_3(fac2)

        
            
class course:
    """Class for course data, this holds the information needed for calculating the workload.
    Also this stores the provisional allotment
    """
    def __init__(self, data):
        self.course_code = data[0]
        self.course_name = data[1]
        self.course_faculty_required = data[2]
        self.num_preferences = 0
        self.preference = []
        self.faculty_list = []
        self.is_ug_course = True

    # any number of preference can be added It is stored as array of arrays
    def add_preference(self,pref_):
        self.preference.append(pref_)
        self.num_preferences += 1

    def assign_faculty(self, faculty):
        self.course_faculty_required -= 1
        self.faculty_list.append(faculty)

    def set_as_pg(self):
        self.is_ug_course = False
    
    def print_course(self):
        print(f"Course code : ", self.course_code)

    def get_requirement(self):
        return self.course_faculty_required

# %%
import pandas as pd

def break_ties():
    pass

def compute_provisional_allotment():

    faculty_requirement = pd.read_csv('facultyRequirement_ug.csv')
    workload_hist = pd.read_csv('work_load_ODD_22.csv') 
    # After each year, the courses are allotted, a function is written to store that in a csv file : work_load_YY_YY.csv
    # As of now, just a single year data is considered
    
    # Routine to have the courses as dictionary or keep it in the list
    course_list_ = list(faculty_requirement['Course'])
    course_req_ = list(faculty_requirement[' Requirement'])

    # Create Course objects
    course_list = []
    for i in range(0,len(course_list_)):
        data = course([course_list_[i], 'UG Course',course_req_[i]])
        course_list.append(data)
        # data.print_course()

    # course_list has all the information needed for allotment

    # Create Faculty objects
    faculty_list_master_data = pd.read_csv('facultyList.csv')  # Has all the faculties name and smail id
    course_pref_data = pd.read_csv('Teaching_Preference.csv')  # Course preference form 
    workload_hist = pd.read_csv('work_load_ODD_22.csv') # Workload history stored every semester
    faculty_on_allotment_roll = list(course_pref_data['Mail id'])

    #Gets the history of the faculty on roll
    w_history = []
    for fac in faculty_on_allotment_roll:
        w_history = workload_hist.loc[workload_hist['Mail id'] == fac]
        for w in w_history:
            course_list[course_list_.find(w)].

    
    



    #Allotment algorithm 
    for i in range(0, NUM_PREFERENCES): # Allotment does in Number of preferences
        for j in range(0, len(course_list)):



compute_provisional_allotment()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-c56140e94624> in <module>
#      40
#      41
# ---> 42 compute_provisional_allotment()
#
# <ipython-input-41-c56140e94624> in compute_provisional_allotment()
#      27     faculty_on_allotment_roll = list(course_pref_data['Mail id'])
#      28
# ---> 29     w
#      30     for fac in faculty_on_allotment_roll:
#      31         w_history = workload_hist.loc[workload_hist['Mail id'] == fac]
#
# NameError: name 'w' is not defined

# %%
# import required modules
from bs4 import BeautifulSoup
# !pip install bs4
import requests

# get URL
page = requests.get("https://math.iitm.ac.in/people/Faculty")

# scrape webpage
soup = BeautifulSoup(page.text, 'html.parser')

# display scraped data
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en">
#  <!--<![endif]-->
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="Mathematics, deptCMS, dptCMS, department, website, IIT, Desto Creative Solutions, Chennai, app, web app, admin dashboard, admin" name="description"/>
#   <meta content="width=device-width,  initial-scale=1, maximum-scale=1" name="viewport">
#    <title>
#     Department of Mathematics | Indian Institute Of Technology Madras , Chennai
#    </title>
#    <link href="https://math.iitm.ac.in/favicon.png" rel="shortcut icon" type="image/x-icon"/>
# ...

# %%
def parse_faculty_name(data):
    for i in range(0, len(data)):
        b = str(data[i])
        b = b[47:-4]
        x = b.find(">")
        data[i] = b[x+1:]
        #print(data[i])
    return data


def parse_faculty_email(data):
    for i in range(0, len(data)):
        b = str(data[i])
        x = b.find("<i class=\"fa fa-envelope-o\"></i>")+34
        y = b.find("<i class=\"fa fa-book\">")-40
        b = b[x:y]
        data[i] = b
        #print(b)
    return data

#<div class="col-sm-9">
import pandas as pd
faculty_list = []
faculty_list = soup.find_all("div", class_="col-sm-9")
#print(len(faculty_list))
#print(str(faculty_list[1]))
faculty_name = soup('p', class_="each-user-title font-bold")
#print(faculty_name)
faculty_name = parse_faculty_name(faculty_name)
faculaty_smail = parse_faculty_email(faculty_list)


faculty_data = pd.DataFrame(list(zip(faculty_name, faculaty_smail)), columns=['Faculty Name', 'Mail id'])
faculty_data['Faculty Name'].str.strip()
faculty_data['Mail id'].str.replace('\xa0\xa0', '')
#print(faculty_data.head())
# writing to csv file
faculty_data.to_csv('facultyList.csv', index=False)
faculty_data1 = pd.read_csv('facultyList.csv', skipinitialspace=True)
faculty_data1.to_csv('facultyList.csv', index=False)
